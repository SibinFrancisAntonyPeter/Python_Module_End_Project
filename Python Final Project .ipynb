# %% [markdown]
# # Python_Module_End_Project

# %%
# Importing Necessary Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("C:/Users/sibin/Downloads/myexcel.xlsx")
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %% [markdown]
# ## Preprocessing :
#
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis

# %%
df['Height'] = np.random.randint(150,180,len(df))

# %%
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0

# %%
# keeping a copy of the original data frame

df1 = df.copy()
df1
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
# Checking the number of rows and columns
df1.shape
# Out:
# (458, 9)

# %%
# Checking for null values

df1.isna().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df1.dropna()
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21     174     235
# 7     Kelly Olynyk  Boston Celtics      41        C   25     161     238
# ..             ...             ...     ...      ...  ...     ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26     158     206
# 452     Trey Lyles       Utah Jazz      41       PF   20     173     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     161     203
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     166     231
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
# Treating null values in column Collage and Salary

df1.replace([""," ","null","none"],np.nan,inplace = True) 
print("\nDataFrame after replace:")
df1
# Out:
# DataFrame after replace:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     163     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     166     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     161     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     159     256
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     166     231
#
#                College     Salary
# ...

# %%
df1.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  164.757642  221.543668  4.833970e+06
# std     15.966837    4.400128    8.837222   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  157.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  165.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  173.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  179.000000  307.000000  2.500000e+07

# %%
# Treating empty values in column Salary 

df1['Salary'].isna().sum()
# Out:
# 11

# %%
df1['Salary'] = df1['Salary'].fillna(df1['Salary'].mean())

# %%
df1.head()
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
#
#    Weight            College        Salary
# 0     180              Texas  7.730337e+06
# 1     235          Marquette  6.796117e+06
# 2     205  Boston University  4.833970e+06
# 3     185      Georgia State  1.148640e+06
# 4     231                NaN  5.000000e+06

# %%
df1['Salary'].isna().sum()
# Out:
# 0

# %%
# Treating empty values in column College

df1['College'].isna().sum()
# Out:
# 84

# %%
df1['College'] = df1['College'].fillna(df1['College'].mode()[0])

# %%
df1.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2   John Holland  Boston Celtics      30       SG   27     163     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     166     231
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.833970e+06
# 3      Georgia State  1.148640e+06
# 4           Kentucky  5.000000e+06

# %%
df1['College'].isna().sum()
# Out:
# 0

# %%
df1.isna().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
# Descriptive ststistics
df1.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.580000e+02
# mean    17.713974   26.934498  164.757642  221.543668  4.833970e+06
# std     15.966837    4.400128    8.837222   26.343200  5.163335e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  157.000000  200.000000  1.100150e+06
# 50%     13.000000   26.000000  165.000000  220.000000  2.862190e+06
# 75%     25.000000   30.000000  173.000000  240.000000  6.323553e+06
# max     99.000000   40.000000  179.000000  307.000000  2.500000e+07

# %%
# To getbasic info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %% [markdown]
# ## 1. Determine the distribution of Players across each team and calculate the percentage split relative to the total number of Players.

# %%
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     163     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     166     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     161     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     159     256
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     166     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
# To get the team count

team_count = df1.groupby('Team')
team_count

# %%
team_count.size()
# Out:
# Team
# Atlanta Hawks             15
# Boston Celtics            15
# Brooklyn Nets             15
# Charlotte Hornets         15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Dallas Mavericks          15
# Denver Nuggets            15
# Detroit Pistons           15
# Golden State Warriors     15
# Houston Rockets           15
# Indiana Pacers            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Memphis Grizzlies         18
# Miami Heat                15
# Milwaukee Bucks           16
# Minnesota Timberwolves    14
# New Orleans Pelicans      19
# New York Knicks           16
# Oklahoma City Thunder     15
# Orlando Magic             14
# Philadelphia 76ers        15
# Phoenix Suns              15
# Portland Trail Blazers    15
# Sacramento Kings          15
# San Antonio Spurs         15
# Toronto Raptors           15
# Utah Jazz                 16
# Washington Wizards        15
# dtype: int64

# %% [markdown]
# #### Finding the percentage split

# %%
t_count = df1['Team'].value_counts() # Count of players in each team
total_count = len(df1)  # Total number of players 
percentage = round((t_count/total_count)*100,2) # Calculating the percentage
print(percentage.head()) # Showing first 5 rows
# Out:
# Team
# New Orleans Pelicans    4.15
# Memphis Grizzlies       3.93
# Utah Jazz               3.49
# New York Knicks         3.49
# Milwaukee Bucks         3.49
# Name: count, dtype: float64

# %%
count_df = pd.DataFrame({
    "Team" : t_count.index,
    "Players Count" : total_count,
    "Percentage" : percentage})

# %%
count_df
# Out:
#                                           Team  Players Count  Percentage
# Team
# New Orleans Pelicans      New Orleans Pelicans            458        4.15
# Memphis Grizzlies            Memphis Grizzlies            458        3.93
# Utah Jazz                            Utah Jazz            458        3.49
# New York Knicks                New York Knicks            458        3.49
# Milwaukee Bucks                Milwaukee Bucks            458        3.49
# Brooklyn Nets                    Brooklyn Nets            458        3.28
# Portland Trail Blazers  Portland Trail Blazers            458        3.28
# Oklahoma City Thunder    Oklahoma City Thunder            458        3.28
# Denver Nuggets                  Denver Nuggets            458        3.28
# Washington Wizards          Washington Wizards            458        3.28
# Miami Heat                          Miami Heat            458        3.28
# Charlotte Hornets            Charlotte Hornets            458        3.28
# ...

# %%
count_df.head()
# Out:
#                                       Team  Players Count  Percentage
# Team
# New Orleans Pelicans  New Orleans Pelicans            458        4.15
# Memphis Grizzlies        Memphis Grizzlies            458        3.93
# Utah Jazz                        Utah Jazz            458        3.49
# New York Knicks            New York Knicks            458        3.49
# Milwaukee Bucks            Milwaukee Bucks            458        3.49

# %% [markdown]
# #### Graphical Representation

# %%
plt.figure(figsize = (9,7))
plt.bar(count_df["Team"],count_df["Percentage"],color= 'indigo',edgecolor='yellow')
plt.title ("Percentage split against each team")
plt.xlabel("Team Names")
plt.ylabel("Percentage")
plt.yticks([1,2,3,4,5,])
plt.xticks(rotation=90)
for i, v in enumerate(count_df['Percentage']):
    plt.text(i, v + 0.5, str(v), ha='center',rotation=90,fontsize=7)
plt.show()

# %% [markdown]
# ### Inference : "New Orleans Pelicans" has the highest percentage of players.

# %% [markdown]
# ## 2.Segregate employees based on their positions within the company.

# %%
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     163     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     166     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     161     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     159     256
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     166     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
# To get the position count
pcount = df1['Position'].value_counts()
pcount
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# #### Segregating Employees

# %%
pcount.index
# Out:
# Index(['SG', 'PF', 'PG', 'SF', 'C'], dtype='object', name='Position')

# %% [markdown]
# pcount.values

# %%
Seg_list = pd.DataFrame({
    "Position" : pcount.index,
    "Employee_Count" : pcount.values
})

# %%
Seg_list
# Out:
#   Position  Employee_Count
# 0       SG             102
# 1       PF             100
# 2       PG              92
# 3       SF              85
# 4        C              79

# %% [markdown]
# #### Graphical Representation

# %%
# BAR CHART
plt.figure(figsize = (9,7))
plt.bar(Seg_list['Position'],Seg_list['Employee_Count'],color = '#9ACD32',edgecolor = 'r')
plt.title('Positional segregation of Employees')
plt.xlabel('Position of employees')
plt.ylabel('Employee Count')
plt.show()

# %%
# PIE CHART
plt.figure(figsize = (9,7))
plt.pie(Seg_list['Employee_Count'],labels = Seg_list['Position'],autopct = '%1.1f%%',startangle = 0, 
        colors = ['palegreen','peru','magenta','lightskyblue','tomato'])
plt.title('Position wise Employee Distribution')
plt.show()

# %% [markdown]
# ### Inference : Position 'SG' has the highest number of players and Position 'C' has the lowest number of players.

# %% [markdown]
# ## 3. Identify the predominant age group among employees.

# %%
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     163     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     166     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     161     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     159     256
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     166     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
Age_group = df1.groupby('Age')
Age_group

# %%
# Quantity of the age groups
Age_group.size()
# Out:
# Age
# 19     2
# 20    19
# 21    19
# 22    26
# 23    41
# 24    47
# 25    46
# 26    36
# 27    41
# 28    31
# 29    28
# 30    31
# 31    22
# 32    13
# 33    14
# 34    10
# 35     9
# 36    10
# 37     4
# 38     4
# 39     2
# 40     3
# dtype: int64

# %% [markdown]
# #### Predominant Age

# %%
Age_group.size().max()
# Out:
# 47

# %%
# Predominat age group is 24( 47nos )

# %%
Age_Group = pd.DataFrame({
    "Name" : df1['Name'],
    "Age" : df1['Age']
})

# %%
Age_Group
# Out:
#               Name  Age
# 0    Avery Bradley   25
# 1      Jae Crowder   25
# 2     John Holland   27
# 3      R.J. Hunter   22
# 4    Jonas Jerebko   29
# ..             ...  ...
# 453   Shelvin Mack   26
# 454      Raul Neto   24
# 455   Tibor Pleiss   26
# 456    Jeff Withey   26
# 457       Priyanka   25
#
# [458 rows x 2 columns]

# %% [markdown]
# #### Creating age groups

# %%
bins = [10,15,20,25,30,35,40,45,50]
labels = ['10-15','15-20','20-25','25-30','30-35','35-40','40-45','45-50']
df1['Age_Group'] = pd.cut(df1['Age'], bins=bins, labels=labels, right=False) # Apply pd.cut() to create the 'Age_Group' column
Age_group = df1[['Name', 'Age', 'Age_Group']].copy() # Created a new DataFrame with Age_Group
Age_group
# Out:
#               Name  Age Age_Group
# 0    Avery Bradley   25     25-30
# 1      Jae Crowder   25     25-30
# 2     John Holland   27     25-30
# 3      R.J. Hunter   22     20-25
# 4    Jonas Jerebko   29     25-30
# ..             ...  ...       ...
# 453   Shelvin Mack   26     25-30
# 454      Raul Neto   24     20-25
# 455   Tibor Pleiss   26     25-30
# 456    Jeff Withey   26     25-30
# 457       Priyanka   25     25-30
#
# [458 rows x 3 columns]

# %%
# finding the predominant age group
Age_group.groupby('Age_Group').size()
# Out:
# C:\Users\sibin\AppData\Local\Temp\ipykernel_10424\2281993889.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Age_group.groupby('Age_Group').size()
# Age_Group
# 10-15      0
# 15-20      2
# 20-25    152
# 25-30    182
# 30-35     90
# 35-40     29
# 40-45      3
# 45-50      0
# dtype: int64

# %% [markdown]
# #### Graphical Representation

# %%
plt.figure(figsize = (9,7))
sns.histplot(Age_group['Age_Group'],bins = 9,color = 'steelblue', edgecolor = 'navy')
plt.title(" Distribution of age group among Employees")
plt.xlabel('Age Groups')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# ### Inference : "25-30" is the predominant age group among the employees

# %% [markdown]
# ## 4. Discover which team and position have the highest salary expenditure.

# %%
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     163     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     166     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     161     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     159     256
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     166     231
#
#                College   Salary Age_Group
# 0                Texas  7730337     25-30
# ...

# %% [markdown]
# #### Finding the Team wise mean of salaries to find which Team has highest salary expenditure.

# %%
Team_Salary = df1.groupby('Team')['Salary'].mean()
Team_Salary
# Out:
# Team
# Atlanta Hawks            4,860,197
# Boston Celtics           4,225,002
# Brooklyn Nets            3,501,898
# Charlotte Hornets        5,222,728
# Chicago Bulls            5,785,559
# Cleveland Cavaliers      7,454,844
# Dallas Mavericks         4,746,582
# Denver Nuggets           4,330,393
# Detroit Pistons          4,477,884
# Golden State Warriors    5,924,600
# Houston Rockets          5,018,868
# Indiana Pacers           4,450,122
# Los Angeles Clippers     6,323,643
# Los Angeles Lakers       4,784,695
# Memphis Grizzlies        5,327,042
# Miami Heat               6,145,574
# Milwaukee Bucks          4,350,220
# Minnesota Timberwolves   4,610,262
# New Orleans Pelicans     4,355,304
# New York Knicks          4,581,494
# Oklahoma City Thunder    6,251,020
# Orlando Magic            4,297,248
# Philadelphia 76ers       2,388,458
# Phoenix Suns             4,229,676
# Portland Trail Blazers   3,220,121
# Sacramento Kings         4,778,911
# ...

# %%
df1['Salary'] = df1['Salary'].apply(int)
pd.options.display.float_format = '{:,.0f}'.format

# %%
# Sorting in ascending order
Team_Salary_sorted = Team_Salary.sort_values(ascending = False)
Team_Salary_sorted
# Out:
# Team
# Cleveland Cavaliers      7,454,844
# Los Angeles Clippers     6,323,643
# Oklahoma City Thunder    6,251,020
# Miami Heat               6,145,574
# Golden State Warriors    5,924,600
# Chicago Bulls            5,785,559
# San Antonio Spurs        5,629,516
# Memphis Grizzlies        5,327,042
# Charlotte Hornets        5,222,728
# Washington Wizards       5,088,576
# Houston Rockets          5,018,868
# Atlanta Hawks            4,860,197
# Los Angeles Lakers       4,784,695
# Sacramento Kings         4,778,911
# Dallas Mavericks         4,746,582
# Toronto Raptors          4,741,174
# Minnesota Timberwolves   4,610,262
# New York Knicks          4,581,494
# Detroit Pistons          4,477,884
# Indiana Pacers           4,450,122
# New Orleans Pelicans     4,355,304
# Milwaukee Bucks          4,350,220
# Denver Nuggets           4,330,393
# Orlando Magic            4,297,248
# Phoenix Suns             4,229,676
# Boston Celtics           4,225,003
# ...

# %% [markdown]
# #### Graphical Representation

# %%
plt.figure(figsize = (9,7))
plt.bar(Team_Salary.index,Team_Salary.values,color = 'darkorange',edgecolor = 'greenyellow')
plt.title('Average Salary by Team')
plt.xlabel('Team Names')
plt.ylabel('Average salary (in Ten lakhs)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Inference : Team "Cleveland Cavaliers" have the highest salary.

# %% [markdown]
# #### Finding the Position wise mean of salaries to find which Position has highest salary expenditure.

# %%
df1.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2   John Holland  Boston Celtics      30       SG   27     163     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     166     231
#
#              College   Salary Age_Group
# 0              Texas  7730337     25-30
# 1          Marquette  6796117     25-30
# 2  Boston University  4833969     25-30
# 3      Georgia State  1148640     20-25
# 4           Kentucky  5000000     25-30

# %%
Position_wise_Salary = df1.groupby('Position')['Salary'].mean()
Position_wise_Salary
# Out:
# Position
# C    5,903,511
# PF   4,570,628
# PG   5,067,227
# SF   4,857,117
# SG   4,034,100
# Name: Salary, dtype: float64

# %%
Position_wise_Salary.max() # Maximum value
# Out:
# 5903510.53164557

# %% [markdown]
# #### Graphical Representation

# %%
plt.figure(figsize = (9,7))
plt.bar(Position_wise_Salary.index,Position_wise_Salary.values,color = 'orchid',edgecolor = 'olivedrab')
plt.title('Average Salary by Position')
plt.xlabel('Position')
plt.ylabel('Average salary (in Ten lakhs)')
plt.show()

# %% [markdown]
# ### Inference : Highest salary is for 'C' position .

# %% [markdown]
# ## 5.Investigate if there's any correlation between age and salary, and represent it visually.

# %%
df1.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2   John Holland  Boston Celtics      30       SG   27     163     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     166     231
#
#              College   Salary Age_Group
# 0              Texas  7730337     25-30
# 1          Marquette  6796117     25-30
# 2  Boston University  4833969     25-30
# 3      Georgia State  1148640     20-25
# 4           Kentucky  5000000     25-30

# %%
# Investigating for corelation
cor = df1['Age'].corr(df1['Salary'])
print(f"Correlation : {cor:.2f}")
# Out:
# Correlation : 0.21

# %% [markdown]
# #### Graphical Representation

# %% [markdown]
# ### Inference : The correlation between Age and Salary is slightly positive, that is When age increases the salary will increase in a slight manner.

# %%
# Scatterplot
plt.figure(figsize = (9,7))
sns.scatterplot(data = df1, x='Age', y = 'Salary',hue ='Position', palette = 'rocket')
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# #### Detailed Analysis:

# %% [raw]
# ✅ General Trend: A weak positive correlation exists—salaries tend to slightly increase with age, especially between 20-30.
# ✅ Clusters: Most data points are concentrated between ages 20-30, with salaries mostly below ₹1 crore (1e7). Fewer data points exist above age 35,         indicating less representation.
# ✅ Outliers: Some 25-30-year-olds earn exceptionally high salaries (2e7)—likely key executives, entrepreneurs, or anomalies.
# ✅ Plateau or Decline: Beyond 30, salary growth slows or stabilizes, with some declines. This may be due to career shifts, industry trends, or dataset      limitations.

# %%
# Correlation Heat map
num_df = df1.select_dtypes(include = ['number'])

plt.figure(figsize = (7,7))
sns.heatmap(num_df.corr(), annot=True, cmap='Spectral', linewidths=0.5)
plt.title('Correlation Heatmap Matrix')
plt.show()

# %% [markdown]
# ### Inference :

# %% [raw]
# ✅ New Orleans Pelicans has the highest percentage of players.
# ✅ Position Breakdown: Shooting Guards (SG) have the highest number of players, while Centers (C) have the lowest.
# ✅ Predominant Age Group: Most players fall in the 25-30 age range.
# ✅ Highest Salary by Position: Centers (C) earn the highest salaries.
# ✅ Age vs. Salary Correlation: There is a slight positive correlation—as age increases, salary increases slightly.
# ✅ Cleveland Cavaliers have the highest team salary.
